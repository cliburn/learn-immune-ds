# %% [markdown]
# # Squidpy for our Visium samples

# %%
import scanpy as sc
import anndata as ad
import squidpy as sq
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
sc.logging.print_header()
print(f"squidpy=={sq.__version__}")
# Out:
# scanpy==1.9.3 anndata==0.8.0 umap==0.5.3 numpy==1.22.1 scipy==1.10.1 pandas==2.0.0 scikit-learn==1.1.2 statsmodels==0.13.2 python-igraph==0.10.2 pynndescent==0.5.8
# squidpy==1.2.3

# %%
import warnings
warnings.simplefilter('ignore', FutureWarning)
warnings.simplefilter('ignore', UserWarning)

# %%
adata = sq.read.visium(
    path='data/spaceranger_count_outs/19-092_RLL',
    counts_file='filtered_feature_bc_matrix.h5'
)

# %%
adata.var_names_make_unique()

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 3254 × 17943
#     obs: 'in_tissue', 'array_row', 'array_col'
#     var: 'gene_ids', 'feature_types', 'genome'
#     uns: 'spatial'
#     obsm: 'spatial'

# %%
sq.pl.spatial_scatter(adata)

# %%
sq.pl.spatial_scatter(adata, color='TAGLN')
