# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt

# %%
n = 10
k = 5
m = 3

# %%
def prob(n, m, k, λ):
    p = 1 - sp.stats.binom(m, λ).pmf(0)
    return sp.stats.binom(n, p).pmf(k)

# %%
ps = [prob(n, m, k, λ) for λ in np.arange(0,1, 0.0001)]

# %%
plt.plot(np.arange(0,1, 0.0001), ps)
