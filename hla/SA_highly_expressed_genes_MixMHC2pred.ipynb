# %% [markdown]
# # MHC Epitope Prediction
#
# Reference: https://github.com/GfellerLab/MixMHC2pred

# %%
import os
import warnings

# %%
warnings.simplefilter('ignore', FutureWarning)

# %% [markdown]
# # S. aureus analysis
#
# Use hihgly expressedd proteins in `sa_highly_expressed_genes.fasta`

# %%
pid = 'sa_highly_expressed_genes'

# %%
import glob
import os
import pandas as pd

# %%
from Bio import SeqIO

# %% [markdown]
# ### Prepare inputs for MixMHC2pred

# %%
fasta_sequences = SeqIO.parse(open(f'{pid}.fasta'),'fasta')
w = 15
for fasta in fasta_sequences:
    name, sequence = fasta.id, str(fasta.seq)
    sequence = '------' + sequence + '------'
    name = name.split('|')[-1]
    with open(f'data/{name}.kmers', 'w') as fo:
        for i in range(6, len(sequence) - (w-1) - 12):
            context = sequence[i-6:i] + sequence[i+w:i+w+6]
            fo.write(sequence[i:i+w] + '\t' + context + '\n')

# %%
alleles = (
    'HLA-DRB1*04:01 HLA-DRB1*04:02 HLA-DRB1*15:01 HLA-DRB1*12:01'.
    replace('HLA-', '').
    replace('*', '_').
    replace(':', '_')
)
alleles
# Out:
# 'DRB1_04_01 DRB1_04_02 DRB1_15_01 DRB1_12_01'

# %% [markdown]
# ### Run MixMHC2pred

# %%
# %%time
ref = 'MixMHC2pred-2.0.2/PWMdef_Human'

outputs = []
infiles = glob.glob('data/*kmers')
for fi in infiles:
    fo = fi.replace('kmers', 'out')
    cmd = f'MixMHC2pred-2.0.2/MixMHC2pred -i {fi} -o {fo} -a {alleles} -f {ref}'
    outputs.append(os.popen(cmd).read())
# Out:
# CPU times: user 5.7 ms, sys: 46.5 ms, total: 52.2 ms
# Wall time: 10.7 s

# %%
print(outputs[0])
# Out:
# Runing MixMHC2pred (v2.0.2) for peptide file: data/A0A0H2XFL0_STAA3.kmers
# Imported 295 peptides. Computing now the PWM-based scores from each peptide.
# Computing now the full scores from each peptide.
# Saving the results in the output file.
# Finished the computations.

# %% [markdown]
# ### Assemble DataFrame from MixMHC2pred outputs

# %%
dfs = []
for fi in infiles:
    protein = fi.split('/')[-1].rstrip('.kmers')
    fo = fi.replace('kmers', 'out')
    df_ = pd.read_table(fo, comment='#')
    df_['protein'] = protein
    dfs.append(df_)
df = pd.concat(dfs)
df = df[df.columns[-1:].tolist() + df.columns[:-1].tolist()]

# %%
df.sample(10)
# Out:
#               protein          Peptide       Context  BestAllele  %Rank_best  \
# 68         ISDC_STAA3  QITVNHSHWITGMSI  NGKLYVEGHKEN  DRB1_12_01      23.700
# 98   A0A0H2XIG1_STAA3  LFFPTGHILLKLVFA  GILIALVICSIC  DRB1_12_01      82.200
# 260        GUAC_STAA3  QKGEHKNVEGKKMFV  GSASEFEHKGSL  DRB1_15_01      17.900
# 128  A0A0H2XEL7_STAA3  LGASYSTSSNNVQVT  SYRTGGTTMAPS  DRB1_04_01       0.303
# 122  A0A0H2XDN8_STAA3  IFKIGHFSIYFILLI  LILFQGGVLLGT  DRB1_12_01      18.400
# 287        GUAC_STAA3  MQQDLQSSISYAGGK  MDTLKEDLKSLR  DRB1_04_02       2.130
# 190        ISDE_STAA3  LVKIAGGENVIKVKD  KSYIGDRQYISS  DRB1_04_02       4.630
# 35         ISDE_STAA3  IVPTTVALTMTLDKL  KSGEFRDLPIVG  DRB1_12_01      37.700
# 134  A0A0H2XDN8_STAA3  LLIGVLLGTFFRSIT  FSIYFIGFIQLI  DRB1_12_01      76.100
# 89   A0A0H2XH75_STAA3  MNYVRSSNKSHGKQN  EKLKLPQIEGAK  DRB1_04_01      22.200
#
#      Core_best  CoreP1_best  SubSpec_best  %Rank_DRB1_04_01  \
# 68   ITVNHSHWI            2             1            32.700
# 98   GHILLKLVF            6             1            92.800
# 260  HKNVEGKKM            5             1            30.800
# 128  YSTSSNNVQ            5             1             0.303
# 122  IGHFSIYFI            4             1            57.600
# 287  LQSSISYAG            5             1             3.300
# 190  IAGGENVIK            4             1             8.430
# 35   TVALTMTLD            5             1            38.600
# 134  IGVLLGTFF            3             1            96.300
# 89   YVRSSNKSH            3             1            22.200
#
#      CoreP1_DRB1_04_01  SubSpec_DRB1_04_01  %Rank_DRB1_04_02  \
# 68                   2                   1             33.40
# 98                   2                   1             88.60
# 260                  2                   1             34.00
# 128                  5                   1             36.10
# 122                  4                   1             48.30
# 287                  5                   1              2.13
# 190                  4                   1              4.63
# 35                   1                   1             50.80
# 134                  5                   1             94.90
# 89                   3                   1             30.40
#
#      CoreP1_DRB1_04_02  SubSpec_DRB1_04_02  %Rank_DRB1_15_01  \
# 68                   2                   1             25.30
# 98                   4                   1             92.00
# 260                  5                   1             17.90
# 128                  5                   1             55.10
# 122                  4                   1             19.40
# 287                  5                   1              6.99
# 190                  4                   1             13.00
# 35                   6                   1             42.10
# 134                  5                   1             93.80
# 89                   4                   1             37.50
#
#      CoreP1_DRB1_15_01  SubSpec_DRB1_15_01  %Rank_DRB1_12_01  \
# 68                   2                   1              23.7
# 98                   1                   1              82.2
# 260                  5                   1              25.5
# 128                  4                   1              55.5
# 122                  4                   1              18.4
# 287                  5                   1              20.0
# 190                  2                   1              17.7
# 35                   4                   1              37.7
# 134                  5                   1              76.1
# 89                   4                   1              39.5
#
#      CoreP1_DRB1_12_01  SubSpec_DRB1_12_01
# 68                   2                   1
# 98                   6                   1
# 260                  5                   1
# 128                  5                   1
# 122                  4                   1
# 287                  5                   1
# 190                  2                   1
# 35                   5                   1
# 134                  3                   1
# 89                   4                   1
