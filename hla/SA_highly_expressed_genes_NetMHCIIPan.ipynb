# %% [markdown]
# # MHC Epitope Prediction
#
# Reference:
#
# - [`epitopepredict`](https://epitopepredict.readthedocs.io/en/latest/description.html#prediction-algorithms)
#   - [Python API](https://epitopepredict.readthedocs.io/en/latest/examples.html)

# %%
import os
import warnings

# %%
warnings.simplefilter('ignore', FutureWarning)

# %%
import epitopepredict as ep
from epitopepredict import base, sequtils, analysis, plotting

# %% [markdown]
# # Get list of predictors
#
# | name	| description |
# |:- | :- |
# | basicmhc1	| built-in MHC-class I predictor |
# | tepitope | implements the TEPITOPEPan method, built in (MHC-II)|
# | netMHCpan | http://www.cbs.dtu.dk/services/NetMHCpan/ (MHC-I) |
# | netMHCIIpan | http://www.cbs.dtu.dk/services/NetMHCIIpan/ (MHC-II) |
# | mhcflurry | https://github.com/openvax/mhcflurry (MHC-I) |
# | IEDB MHC-I tools | http://tools.immuneepitope.org/mhci/download/ |
#
# Only `tepitope`, `netmhciipan`, `netmhcpan`, `mhcflurry` are installed locally.

# %%
print(base.predictors)
# Out:
# ['basicmhc1', 'tepitope', 'netmhciipan', 'netmhcpan', 'mhcflurry', 'iedbmhc1', 'iedbmhc2']

# %% [markdown]
# ## S. aureus analysis
#
# Use hihgly expressedd proteins in `sa_highly_expressed_genes.fasta`

# %%
pid = 'sa_highly_expressed_genes'

# %%
df = sequtils.fasta_to_dataframe(f'{pid}.fasta')

# %% [markdown]
# run predictions for a protein sequence:

# %%
alleles = """HLA-DRB1*04:01
HLA-DRB1*04:02
HLA-DRB1*15:01
HLA-DRB1*12:01""".split()

# %%
# %%time

np = 8
for predictor in ['tepitope', 'netmhciipan']:
    p = base.get_predictor()
    p.predict_proteins(df, 
                       length=11, 
                       alleles=alleles,
                       save=True, 
                       path=f'{pid}.{predictor}',
                       threads=np)
# Out:
# predictions done for 27 sequences in 4 alleles
# results saved to /Users/ccc14/learning/learn-immune-ds/hla/sa_highly_expressed_genes.tepitope
# predictions done for 27 sequences in 4 alleles
# results saved to /Users/ccc14/learning/learn-immune-ds/hla/sa_highly_expressed_genes.netmhciipan
# CPU times: user 78.5 ms, sys: 69.5 ms, total: 148 ms
# Wall time: 2.52 s

# %% [markdown]
# ### Load and analyze

# %%
predictor = 'netmhciipan'
path = f'{pid}.{predictor}'
p.load(path=path)

# %% [markdown]
# get all the binders using the current data loaded into the predictor

# %%
#default is to use percentile cutoff per allele, returns a dataframe
binders = p.get_binders(cutoff=.95)

# %%
binders.shape
# Out:
# (2054, 7)

# %%
binders.sort_values('score', ascending=False).head(25)
# Out:
#             allele       core                            name      peptide  \
# 0    HLA-DRB1*1501  MRIIKYLTI            sp_Q2FHU8_ISDE_STAA3  MRIIKYLTILV
# 184  HLA-DRB1*1201  LVILLVITI  tr_A0A0H2XDN8_A0A0H2XDN8_STAA3  VLLVILLVITI
# 186  HLA-DRB1*1201  LVILLVITI  tr_A0A0H2XDN8_A0A0H2XDN8_STAA3  LVILLVITILL
# 185  HLA-DRB1*1201  LVILLVITI  tr_A0A0H2XDN8_A0A0H2XDN8_STAA3  LLVILLVITIL
# 110  HLA-DRB1*1501  MVLFALILF  tr_A0A0H2XDN8_A0A0H2XDN8_STAA3  TMVLFALILFQ
# 111  HLA-DRB1*1501  MVLFALILF  tr_A0A0H2XDN8_A0A0H2XDN8_STAA3  MVLFALILFQG
# 109  HLA-DRB1*1501  MVLFALILF  tr_A0A0H2XDN8_A0A0H2XDN8_STAA3  ITMVLFALILF
# 39   HLA-DRB1*1501  LRKFILIIL  tr_A0A0H2XDN8_A0A0H2XDN8_STAA3  LRKFILIILVG
# 38   HLA-DRB1*1501  LRKFILIIL  tr_A0A0H2XDN8_A0A0H2XDN8_STAA3  RLRKFILIILV
# 37   HLA-DRB1*1501  LRKFILIIL  tr_A0A0H2XDN8_A0A0H2XDN8_STAA3  SRLRKFILIIL
# 222  HLA-DRB1*1501  MVMIGSLFA            sp_Q2FH96_GUAC_STAA3  ASMVMIGSLFA
# 224  HLA-DRB1*1501  MVMIGSLFA            sp_Q2FH96_GUAC_STAA3  MVMIGSLFAAH
# 223  HLA-DRB1*1501  MVMIGSLFA            sp_Q2FH96_GUAC_STAA3  SMVMIGSLFAA
# 93   HLA-DRB1*1501  LVNFGRFPY  tr_A0A0H2XFV3_A0A0H2XFV3_STAA3  QLVNFGRFPYS
# 23   HLA-DRB1*1501  LVLFVSKII            sp_Q2FK08_LRGA_STAA3  LVLFVSKIIES
# 94   HLA-DRB1*1501  LVNFGRFPY  tr_A0A0H2XFV3_A0A0H2XFV3_STAA3  LVNFGRFPYSK
# 92   HLA-DRB1*1501  LVNFGRFPY  tr_A0A0H2XFV3_A0A0H2XFV3_STAA3  EQLVNFGRFPY
# 21   HLA-DRB1*1501  LVLFVSKII            sp_Q2FK08_LRGA_STAA3  IALVLFVSKII
# 22   HLA-DRB1*1501  LVLFVSKII            sp_Q2FK08_LRGA_STAA3  ALVLFVSKIIE
# 223  HLA-DRB1*1201  LVIVSVLVS  tr_A0A0H2XDN8_A0A0H2XDN8_STAA3  ILLVIVSVLVS
# 224  HLA-DRB1*1201  LVIVSVLVS  tr_A0A0H2XDN8_A0A0H2XDN8_STAA3  LLVIVSVLVSV
# 225  HLA-DRB1*1201  LVIVSVLVS  tr_A0A0H2XDN8_A0A0H2XDN8_STAA3  LVIVSVLVSVS
# 56   HLA-DRB1*1501  VVIFQAITN  tr_A0A0H2XDN8_A0A0H2XDN8_STAA3  VVIFQAITNNR
# 55   HLA-DRB1*1501  VVIFQAITN  tr_A0A0H2XDN8_A0A0H2XDN8_STAA3  SVVIFQAITNN
# 54   HLA-DRB1*1501  VVIFQAITN  tr_A0A0H2XDN8_A0A0H2XDN8_STAA3  TSVVIFQAITN
#
#      pos  rank    score
# 0      0   1.0  7.30000
# 184  184   1.0  6.88208
# 186  186   1.0  6.88208
# 185  185   1.0  6.88208
# 110  110   1.0  6.80000
# 111  111   1.0  6.80000
# 109  109   1.0  6.80000
# 39    39   1.0  6.80000
# 38    38   1.0  6.80000
# 37    37   1.0  6.80000
# 222  222   1.0  6.60000
# 224  224   1.0  6.60000
# 223  223   1.0  6.60000
# 93    93   1.0  6.50000
# 23    23   1.0  6.50000
# 94    94   1.0  6.50000
# 92    92   1.0  6.50000
# 21    21   1.0  6.50000
# 22    22   1.0  6.50000
# 223  223   4.0  6.34975
# 224  224   4.0  6.34975
# 225  225   4.0  6.34975
# 56    56   7.0  6.30000
# 55    55   7.0  6.30000
# 54    54   7.0  6.30000

# %% [markdown]
# get binders for only one protein by top median rank

# %%
name = df.iloc[0,0]
name
# Out:
# 'sp_Q2FH96_GUAC_STAA3'

# %%
p.get_binders(name=name, cutoff=5, cutoff_method='rank').sort_values('rank')
# Out:
#             allele       core                  name      peptide  pos  rank  \
# 222  HLA-DRB1*0401  MVMIGSLFA  sp_Q2FH96_GUAC_STAA3  ASMVMIGSLFA  222   1.0
# 224  HLA-DRB1*1201  MVMIGSLFA  sp_Q2FH96_GUAC_STAA3  MVMIGSLFAAH  224   1.0
# 223  HLA-DRB1*1201  MVMIGSLFA  sp_Q2FH96_GUAC_STAA3  SMVMIGSLFAA  223   1.0
# 222  HLA-DRB1*1201  MVMIGSLFA  sp_Q2FH96_GUAC_STAA3  ASMVMIGSLFA  222   1.0
# 224  HLA-DRB1*1501  MVMIGSLFA  sp_Q2FH96_GUAC_STAA3  MVMIGSLFAAH  224   1.0
# 223  HLA-DRB1*1501  MVMIGSLFA  sp_Q2FH96_GUAC_STAA3  SMVMIGSLFAA  223   1.0
# 224  HLA-DRB1*0402  MVMIGSLFA  sp_Q2FH96_GUAC_STAA3  MVMIGSLFAAH  224   1.0
# 222  HLA-DRB1*1501  MVMIGSLFA  sp_Q2FH96_GUAC_STAA3  ASMVMIGSLFA  222   1.0
# 222  HLA-DRB1*0402  MVMIGSLFA  sp_Q2FH96_GUAC_STAA3  ASMVMIGSLFA  222   1.0
# 223  HLA-DRB1*0401  MVMIGSLFA  sp_Q2FH96_GUAC_STAA3  SMVMIGSLFAA  223   1.0
# 224  HLA-DRB1*0401  MVMIGSLFA  sp_Q2FH96_GUAC_STAA3  MVMIGSLFAAH  224   1.0
# 223  HLA-DRB1*0402  MVMIGSLFA  sp_Q2FH96_GUAC_STAA3  SMVMIGSLFAA  223   1.0
# 59   HLA-DRB1*1201  FYIMHRFDE  sp_Q2FH96_GUAC_STAA3  DYFYIMHRFDE   59   4.0
# 138  HLA-DRB1*0401  FVIAGNVGT  sp_Q2FH96_GUAC_STAA3  DSFVIAGNVGT  138   4.0
# 0    HLA-DRB1*1501  MKIFDYEDI  sp_Q2FH96_GUAC_STAA3  MKIFDYEDIQL    0   4.0
# 61   HLA-DRB1*1201  FYIMHRFDE  sp_Q2FH96_GUAC_STAA3  FYIMHRFDEEA   61   4.0
# 140  HLA-DRB1*0401  FVIAGNVGT  sp_Q2FH96_GUAC_STAA3  FVIAGNVGTPE  140   4.0
# 60   HLA-DRB1*1201  FYIMHRFDE  sp_Q2FH96_GUAC_STAA3  YFYIMHRFDEE   60   4.0
# 218  HLA-DRB1*0402  IRFGASMVM  sp_Q2FH96_GUAC_STAA3  IRFGASMVMIG  218   4.0
# 217  HLA-DRB1*0402  IRFGASMVM  sp_Q2FH96_GUAC_STAA3  SIRFGASMVMI  217   4.0
# 216  HLA-DRB1*0402  IRFGASMVM  sp_Q2FH96_GUAC_STAA3  KSIRFGASMVM  216   4.0
# 139  HLA-DRB1*0401  FVIAGNVGT  sp_Q2FH96_GUAC_STAA3  SFVIAGNVGTP  139   4.0
# 217  HLA-DRB1*1501  IRFGASMVM  sp_Q2FH96_GUAC_STAA3  SIRFGASMVMI  217   5.0
# 218  HLA-DRB1*1501  IRFGASMVM  sp_Q2FH96_GUAC_STAA3  IRFGASMVMIG  218   5.0
# 216  HLA-DRB1*1501  IRFGASMVM  sp_Q2FH96_GUAC_STAA3  KSIRFGASMVM  216   5.0
#
#        score
# 222  5.00000
# 224  4.79558
# 223  4.79558
# 222  4.79558
# 224  6.60000
# 223  6.60000
# 224  5.58000
# 222  6.60000
# 222  5.58000
# 223  5.00000
# 224  5.00000
# 223  5.58000
# 59   3.37585
# 138  3.78000
# 0    5.40000
# 61   3.37585
# 140  3.78000
# 60   3.37585
# 218  3.70000
# 217  3.70000
# 216  3.70000
# 139  3.78000
# 217  5.38000
# 218  5.38000
# 216  5.38000

# %% [markdown]
# get all promiscuous binders

# %%
pb = p.promiscuous_binders(n=2, cutoff=.95)

# %%
pb.shape
# Out:
# (213, 8)

# %%
pb.head(3)
# Out:
#          peptide  pos                            name  alleles       core  \
# 46   ASMVMIGSLFA  222            sp_Q2FH96_GUAC_STAA3        4  MVMIGSLFA
# 58   AVQIMQTLKML  170  tr_A0A0H2XFV3_A0A0H2XFV3_STAA3        4  VQIMQTLKM
# 660  LLLLILLTIIS   10  tr_A0A0H2XIG1_A0A0H2XIG1_STAA3        4  LLILLTIIS
#
#        score      mean  median_rank
# 46   6.60000  5.493895          1.0
# 58   6.25442  5.623605          1.0
# 660  5.30000  5.036600          1.0

# %% [markdown]
# find clusters of binders in these results

# %%
cl = analysis.find_clusters(pb, dist=9, min_size=3)

# %%
cl
# Out:
#                               name  start  end  binders  length
# 4             sp_Q2FHU7_ISDF_STAA3    122  163        8      41
# 19  tr_A0A0H2XDN8_A0A0H2XDN8_STAA3    178  206        7      28
# 17  tr_A0A0H2XDN8_A0A0H2XDN8_STAA3     99  126        7      27
# 40  tr_A0A0H2XIG1_A0A0H2XIG1_STAA3    134  167        6      33
# 7             sp_Q2FHU8_ISDE_STAA3      0   30        6      30
# 36  tr_A0A0H2XI76_A0A0H2XI76_STAA3      0   27        6      27
# 31  tr_A0A0H2XEB0_A0A0H2XEB0_STAA3      0   22        6      22
# 38  tr_A0A0H2XIG1_A0A0H2XIG1_STAA3      4   24        5      20
# 39  tr_A0A0H2XIG1_A0A0H2XIG1_STAA3     89  119        4      30
# 23  tr_A0A0H2XE68_A0A0H2XE68_STAA3      8   34        4      26
# 13            sp_Q2FK08_LRGA_STAA3     41   61        4      20
# 2             sp_Q2FHU7_ISDF_STAA3      6   24        4      18
# 27  tr_A0A0H2XE68_A0A0H2XE68_STAA3    195  212        4      17
# 20  tr_A0A0H2XDN8_A0A0H2XDN8_STAA3    223  242        3      19
# 22  tr_A0A0H2XDN8_A0A0H2XDN8_STAA3    263  282        3      19
# 15  tr_A0A0H2XDN8_A0A0H2XDN8_STAA3     39   56        3      17
# 14            sp_Q2FK08_LRGA_STAA3     98  114        3      16
# 21  tr_A0A0H2XDN8_A0A0H2XDN8_STAA3    240  256        3      16
# 3             sp_Q2FHU7_ISDF_STAA3     98  113        3      15
# 10            sp_Q2FHV0_ISDC_STAA3     63   78        3      15
# 11            sp_Q2FI12_PUR7_STAA3     85  100        3      15
# 18  tr_A0A0H2XDN8_A0A0H2XDN8_STAA3    128  143        3      15
# 26  tr_A0A0H2XE68_A0A0H2XE68_STAA3    113  128        3      15
# 28  tr_A0A0H2XE68_A0A0H2XE68_STAA3    233  248        3      15
# 5             sp_Q2FHU7_ISDF_STAA3    189  208        2      19
# 33  tr_A0A0H2XGZ9_A0A0H2XGZ9_STAA3     27   46        2      19
# 35  tr_A0A0H2XHK0_A0A0H2XHK0_STAA3      2   20        2      18
# 42  tr_A0A0H2XIG1_A0A0H2XIG1_STAA3    293  311        2      18
# 8             sp_Q2FHU8_ISDE_STAA3     32   49        2      17
# 16  tr_A0A0H2XDN8_A0A0H2XDN8_STAA3     77   93        2      16
# 0             sp_Q2FH96_GUAC_STAA3    218  233        2      15
# 12            sp_Q2FK08_LRGA_STAA3     19   33        2      14
# 6             sp_Q2FHU7_ISDF_STAA3    306  319        2      13
# 9             sp_Q2FHV0_ISDC_STAA3     13   26        2      13
# 24  tr_A0A0H2XE68_A0A0H2XE68_STAA3     75   88        2      13
# 30  tr_A0A0H2XE68_A0A0H2XE68_STAA3    316  329        2      13
# 32  tr_A0A0H2XEX9_A0A0H2XEX9_STAA3    242  255        2      13
# 34  tr_A0A0H2XH48_A0A0H2XH48_STAA3     74   87        2      13
# 41  tr_A0A0H2XIG1_A0A0H2XIG1_STAA3    223  236        2      13
# 43  tr_A0A0H2XIG9_A0A0H2XIG9_STAA3     73   86        2      13
# 44  tr_A0A0H2XKM7_A0A0H2XKM7_STAA3      5   18        2      13
# 1             sp_Q2FH96_GUAC_STAA3    311  323        2      12
# 25  tr_A0A0H2XE68_A0A0H2XE68_STAA3     98  110        2      12
# 29  tr_A0A0H2XE68_A0A0H2XE68_STAA3    257  269        2      12
# 37  tr_A0A0H2XI76_A0A0H2XI76_STAA3    232  244        2      12
